# %% [markdown]
# <a href="https://colab.research.google.com/github/Silver-birder/DEMO-PaddlePaddle-PaddleHub-ERNIE-ViLG/blob/main/src/DEMO_PaddlePaddle_PaddleHub_ERNIE_ViLG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DEMO - PaddlePaddle/PaddleHub ERNIE-ViLG
#
# https://github.com/PaddlePaddle/PaddleHub/tree/develop/modules/image/text_to_image/ernie_vilg

# %%
# !pip install paddlepaddle-gpu -U
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 394.0 MB 25 kB/s
# ...
#      |████████████████████████████████| 394 kB 25.9 MB/s
# ...

# %%
# !pip install paddlehub==2.1.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 211 kB 35.6 MB/s
# ...
#      |████████████████████████████████| 1.6 MB 47.7 MB/s
# ...
#      |████████████████████████████████| 3.0 MB 55.4 MB/s
# ...
#      |████████████████████████████████| 181 kB 75.0 MB/s
# ...
#      |████████████████████████████████| 4.9 MB 60.5 MB/s
# ...
#      |████████████████████████████████| 79 kB 8.9 MB/s
# ...
#      |████████████████████████████████| 86 kB 6.7 MB/s
# ...
#      |████████████████████████████████| 43 kB 2.2 MB/s
# ...
#      |████████████████████████████████| 112 kB 65.2 MB/s
# ...
#      |████████████████████████████████| 101 kB 12.4 MB/s
# ...
#      |████████████████████████████████| 1.3 MB 54.3 MB/s
# ...
#      |████████████████████████████████| 365 kB 69.9 MB/s
# ...
#      |████████████████████████████████| 120 kB 72.9 MB/s
# ...
#      |████████████████████████████████| 212 kB 72.0 MB/s
# ...
#      |████████████████████████████████| 127 kB 64.2 MB/s
# ...

# %%
import paddlehub
paddlehub.server_check()
# Out:
# [2022-09-02 13:39:03,661] [    INFO] - Request Hub-Server successfully.
# True

# %%
# !hub install ernie_vilg
# Out:
# Download https://bj.bcebos.com/paddlehub/paddlehub_dev/ernie_vilg.tar.gz
# [##################################################] 100.00%
# Decompress /root/.paddlehub/tmp/tmpcm_ybjii/ernie_vilg.tar.gz
# [##################################################] 100.00%
# [2022-09-02 13:39:18,132] [    INFO] - Successfully installed dependent packages.
# [2022-09-02 13:39:18,211] [    INFO] - Successfully installed ernie_vilg-1.0.0

# %%
# !hub run ernie_vilg --text_prompts "卡哇伊,女孩,御宅族" --style "卡通" --topk 6 --output_dir ernie_vilg_out
# Out:
# 100% 100/100 [00:37<00:00,  6.13%/s]Saving Images...
# Done
# 100% 100/100 [00:50<00:00,  1.99%/s]
# [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x1024 at 0x7F5B5C583590>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x1024 at 0x7F5B5A821F50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x1024 at 0x7F5B5A821890>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x1024 at 0x7F5B5A82C050>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x1024 at 0x7F5B5A82C210>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x1024 at 0x7F5B5A82CFD0>]

# %% [markdown]
# ![卡哇伊,女孩,御宅族_0.png](data:image/png;base64,...)
